# %%
import tweepy as tw
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

# %%
consumer_key = 'epWw8VILVgHNQ7tatmpTuBZ4M'
Secret_key ='W7tcsyVa1ClOiCccKnIrwxhSFoa8u4D91FqeLk9KR83Xd936EI'
access_token = '1176589291838988288-d3W3sxBTUXGmz4dusWBkGVLKP6nTPR'
Access_Token_Secret = 'f6wNlC0kN3FqVN8yQovpe4rcHPdQOPBKH8ftDu4iN78gh'

# %%
auth = tw.OAuthHandler(consumer_key, Secret_key)
auth.set_access_token(access_token, Access_Token_Secret)
api= tw.API(auth, wait_on_rate_limit=True)

# %%
api.

# %%
hashtag = '$TSLA'
query =tw.Cursor(api.search_tweets, q=hashtag).items(1000)
tweets =[{'Tweets':tweet.text, 'Timestamp': tweet.created_at} for tweet in query]
#print(tweets)
# Out:
# [{'Tweets': '@NatalieK131 What was $TSLA share price in 2025?', 'Timestamp': datetime.datetime(2022, 1, 30, 20, 26, 47, tzinfo=datetime.timezone.utc)}, {'Tweets': 'RT @Pmgraham86: This is incredible insight from a current Tesla employee $TSLA https://t.co/RKRr4s0d7w', 'Timestamp': datetime.datetime(2022, 1, 30, 20, 26, 47, tzinfo=datetime.timezone.utc)}, {'Tweets': 'RT @ValueAnalyst1: $TSLA will triple in 2022 🚀🌕 https://t.co/vSx7KzfnoQ', 'Timestamp': datetime.datetime(2022, 1, 30, 20, 26, 42, tzinfo=datetime.timezone.utc)}, {'Tweets': 'An average Long Range Model Y at $61k, with a cost of $36,000 gives Tesla a gross profit of ~70% per Y sold. \n\nMarg… https://t.co/E1JFhDABGX', 'Timestamp': datetime.datetime(2022, 1, 30, 20, 26, 38, tzinfo=datetime.timezone.utc)}, {'Tweets': 'RT @EdLudlow: Coming up on Bloomberg @technology tonight. @emilychangtv and I speak to @david_colombo_. The 19 year old $TSLA hacker and cy…', 'Timestamp': datetime.datetime(2022, 1, 30, 20, 26, 16, tzinfo=datetime.timezone.utc)}, {'Tweets': 'RT @ByeonChansoo: Can we please make America S3XY again? @POTUS  $TSLA @elonmusk \n\n@WholeMarsBlog @28delayslater https://t.co/xNXsjkchCR', 'Timestamp': datetime.datetime(2022, 1, 30, 20, 26, 12, tzinfo=datetime.timezone.utc)}, {'Tweets': 'RT @ValueAnalyst1: $TSLA will triple in 2022 🚀🌕 https://t.co/qRm2xyvZD5', 'Timestamp': datetime.datetime(2022, 1, 30, 20, 26, 7, tzinfo=datetime.timezone.utc)}, {'Tweets': 'RT @BestRapVids: You NO LONGER NEED TO MAKE A PURCHASE to claim 3 FREE STOCKS from here!!!\n\nArticle: https://t.co/Jr85M3uVOd\n\n#Stockmarket…', 'Timestamp': datetime.datetime(2022, 1, 30, 20, 25, 54, tzinfo=datetime.timezone.utc)}, {'Tweets': 'RT @Pmgraham86: This is incredible insight from a current Tesla employee $TSLA https://t.co/RKRr4s0d7w', 'Timestamp': datetime.datetime(2022, 1, 30, 20, 25, 52, tzinfo=datetime.timezone.utc)}, {'Tweets': 'RT @WholeMarsBlog: Honestly, if Tesla AI can make my car drive through all of this with zero takeovers, I bet it could make a humanoid robo…', 'Timestamp': datetime.datetime(2022, 1, 30, 20, 25, 47, tzinfo=datetime.timezone.utc)}, {'Tweets': '$SPX it’s 5x💯 SPX 500 Index \n\nFutures 💚💜❤️\n\nFed Chairman Powell noted that the Fed’s next meeting in March is likel… https://t.co/FIiuxdqiEC', 'Timestamp': datetime.datetime(2022, 1, 30, 20, 25, 13, tzinfo=datetime.timezone.utc)}, {'Tweets': 'Euro Weekly Fundamental Forecast: $EURUSD Slide to Continue \n\n$TSLA $NKE $AAPL $LCID $MSFT $FB $SNAP $GOOG $NFT… https://t.co/xGEEs5WEor', 'Timestamp': datetime.datetime(2022, 1, 30, 20, 25, 10, tzinfo=datetime.timezone.utc)}, {'Tweets': '@pedro_trigueira @GerberKawasaki I don’t care about the $, I hate going to gas stations. There’s never a convenient… https://t.co/HmzzJGD6Kh', 'Timestamp': datetime.datetime(2022, 1, 30, 20, 25, tzinfo=datetime.timezone.utc)}, {'Tweets': 'RT @WholeMarsBlog: Honestly, if Tesla AI can make my car drive through all of this with zero takeovers, I bet it could make a humanoid robo…', 'Timestamp': datetime.datetime(2022, 1, 30, 20, 24, 54, tzinfo=datetime.timezone.utc)}, {'Tweets': 'RT @GerberKawasaki: Not going to gas stations ever again is one of the simple pleasures of going EV. Saves time and money. #tesla $tsla $gg…', 'Timestamp': datetime.datetime(2022, 1, 30, 20, 24, 54, tzinfo=datetime.timezone.utc)}, {'Tweets': 'RT @ICannot_Enough: @elonmusk @POTUS $GM vs. $TSLA Q4 2021 EV Sales: https://t.co/ruMgMsrgZV', 'Timestamp': datetime.datetime(2022, 1, 30, 20, 24, 27, tzinfo=datetime.timezone.utc)}, {'Tweets': 'What are your thoughts on how the markets will play out for 🚨(1/31)🚨...\n📈📈//📉📉?!    🤔💭👇👇\n\n$Spy $Tsla $Qqq $Pfe $V $F $Aapl', 'Timestamp': datetime.datetime(2022, 1, 30, 20, 24, 22, tzinfo=datetime.timezone.utc)}, {'Tweets': 'You NO LONGER NEED TO MAKE A PURCHASE to claim 3 FREE STOCKS from here!!!\n\nArticle: https://t.co/Jr85M3uVOd… https://t.co/vgGhNF5Tn0', 'Timestamp': datetime.datetime(2022, 1, 30, 20, 24, 17, tzinfo=datetime.timezone.utc)},  ...
